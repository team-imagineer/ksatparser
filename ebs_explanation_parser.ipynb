# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from pdf2image import convert_from_path
import cv2
from pathlib import Path
from tqdm import tqdm
import math
import pdfplumber
import pytesseract as pyt
import tempfile
# %matplotlib inline

from ksatparser.utils import *
from ksatparser.problem_parser import extract_T
from ksatparser.solution_parser import *

# %%
# path
test_name = "2022_6_media"
pdf_dir = Path("pdf/explanation/")
output_dir = Path("explanation_output")
pdf_path = pdf_dir/(test_name+".pdf")

# %%
imgs = pdf2pngs(pdf_path)
img = imgs[0]

# %%
imshow(img)

# %%
parse_ebs_solution(pdf_path, output_dir)
# Out:
# ##########
# [공통:
# [1~3]
# [1~3]
# [주제]
# [오답피하기]
# #########
# 1~3
# 1~3
# 주제
# 오답피하기
# 지문 word
# [{'text': '[1~3]', 'x0': 85.08, 'x1': 110.21255999999998, 'top': 239.1168, 'doctop': 239.1168, 'bottom': 250.15679999999998, 'upright': True, 'direction': 1}, {'text': '[1~3]', 'x0': 85.08, 'x1': 110.21255999999998, 'top': 274.2768000000001, 'doctop': 274.2768000000001, 'bottom': 285.31680000000006, 'upright': True, 'direction': 1}]
# 문제 word
# [{'text': '22.06.16', 'x0': 474.71999999999997, 'x1': 510.2709, 'top': 99.44999999999993, 'doctop': 99.44999999999993, 'bottom': 108.44999999999993, 'upright': True, 'direction': 1}, {'text': '01.', 'x0': 93.11999999999999, 'x1': 107.346864, 'top': 149.05319999999995, 'doctop': 149.05319999999995, 'bottom': 159.01319999999998, 'upright': True, 'direction': 1}, {'text': '02.', 'x0': 135.72, 'x1': 149.94686399999998, 'top': 149.05319999999995, 'doctop': 149.05319999999995, 'bottom': 159.01319999999998, 'upright': True, 'direction': 1}, {'text': '03.', 'x0': 178.2, 'x1': 192.426864, 'top': 149.05319999999995, 'doctop': 149.05319999999995, 'bottom': 159.01319999999998, 'upright': True, 'direction': 1}, {'text': '04.', 'x0': 220.67999999999998, 'x1': 234.90686399999996, 'top': 149.05319999999995, 'doctop': 149.05319999999995, 'bottom': 159.01319999999998, 'upright': True, 'direction': 1}, {'text': '05.', 'x0': 263.28, 'x1': 277.506864, 'top': 149.05319999999995, 'doctop': 149.05319999999995, 'bottom': 159.01319999999998, 'upright': True, 'direction': 1}, {'text': '06.', 'x0': 305.76, 'x1': 319.986864, 'top': 149.05319999999995, 'doctop': 149.05319999999995, 'bottom': 159.01319999999998, 'upright': True, 'direction': 1}, {'text': '07.', 'x0': 348.24, 'x1': 362.46686400000004, 'top': 149.05319999999995, 'doctop': 149.05319999999995, 'bottom': 159.01319999999998, 'upright': True, 'direction': 1}, {'text': '08.', 'x0': 390.84, 'x1': 405.066864, 'top': 149.05319999999995, 'doctop': 149.05319999999995, 'bottom': 159.01319999999998, 'upright': True, 'direction': 1}, {'text': '09.', 'x0': 433.32, 'x1': 447.546864, 'top': 149.05319999999995, 'doctop': 149.05319999999995, 'bottom': 159.01319999999998, 'upright': True, 'direction': 1}, {'text': '10.', 'x0': 475.79999999999995, 'x1': 490.026864, 'top': 149.05319999999995, 'doctop': 149.05319999999995, 'bottom': 159.01319999999998, 'upright': True, 'direction': 1}, {'text': '11.', 'x0': 93.11999999999999, 'x1': 107.346864, 'top': 167.53319999999997, 'doctop': 167.53319999999997, 'bottom': 177.4932, 'upright': True, 'direction': 1}, {'text': '12.', 'x0': 135.72, 'x1': 149.94686399999998, 'top': 167.53319999999997, 'doctop': 167.53319999999997, 'bottom': 177.4932, 'upright': True, 'direction': 1}, {'text': '13.', 'x0': 178.2, 'x1': 192.426864, 'top': 167.53319999999997, 'doctop': 167.53319999999997, 'bottom': 177.4932, 'upright': True, 'direction': 1}, {'text': '14.', 'x0': 220.67999999999998, 'x1': 234.90686399999996, 'top': 167.53319999999997, 'doctop': 167.53319999999997, 'bottom': 177.4932, 'upright': True, 'direction': 1}, {'text': '15.', 'x0': 263.28, 'x1': 277.506864, 'top': 167.53319999999997, 'doctop': 167.53319999999997, 'bottom': 177.4932, 'upright': True, 'direction': 1}, {'text': '16.', 'x0': 305.76, 'x1': 319.986864, 'top': 167.53319999999997, 'doctop': 167.53319999999997, 'bottom': 177.4932, 'upright': True, 'direction': 1}, {'text': '17.', 'x0': 348.24, 'x1': 362.46686400000004, 'top': 167.53319999999997, 'doctop': 167.53319999999997, 'bottom': 177.4932, 'upright': True, 'direction': 1}, {'text': '18.', 'x0': 390.84, 'x1': 405.066864, 'top': 167.53319999999997, 'doctop': 167.53319999999997, 'bottom': 177.4932, 'upright': True, 'direction': 1}, {'text': '19.', 'x0': 433.32, 'x1': 447.546864, 'top': 167.53319999999997, 'doctop': 167.53319999999997, 'bottom': 177.4932, 'upright': True, 'direction': 1}, {'text': '20.', 'x0': 475.79999999999995, 'x1': 490.026864, 'top': 167.53319999999997, 'doctop': 167.53319999999997, 'bottom': 177.4932, 'upright': True, 'direction': 1}, {'text': '21.', 'x0': 93.11999999999999, 'x1': 107.346864, 'top': 186.01319999999998, 'doctop': 186.01319999999998, 'bottom': 195.97320000000002, 'upright': True, 'direction': 1}, {'text': '22.', 'x0': 135.72, 'x1': 149.94686399999998, 'top': 186.01319999999998, 'doctop': 186.01319999999998, 'bottom': 195.97320000000002, 'upright': True, 'direction': 1}, {'text': '23.', 'x0': 178.2, 'x1': 192.426864, 'top': 186.013199 ...
# ##########
# [오답피하기]
# [오답피하기]
# [4~9]
# [4~9]
# [주제]
# #########
# 오답피하기
# 오답피하기
# 4~9
# 4~9
# 주제
# 지문 word
# [{'text': '[4~9]', 'x0': 85.08, 'x1': 110.21255999999998, 'top': 539.4767999999999, 'doctop': 1380.4768, 'bottom': 550.5168, 'upright': True, 'direction': 1}, {'text': '[4~9]', 'x0': 85.08, 'x1': 110.21255999999998, 'top': 574.6368, 'doctop': 1415.6368, 'bottom': 585.6768, 'upright': True, 'direction': 1}]
# 문제 word
# [{'text': '3.', 'x0': 85.08, 'x1': 94.732272, 'top': 257.83680000000004, 'doctop': 1098.8368, 'bottom': 268.8768, 'upright': True, 'direction': 1}]
# ##########
# [주제]
# [오답피하기]
# #########
# 주제
# 오답피하기
# 지문 word
# []
# 문제 word
# [{'text': '4.', 'x0': 85.08, 'x1': 94.732272, 'top': 292.9968, 'doctop': 1974.9968, 'bottom': 304.03679999999997, 'upright': True, 'direction': 1}, {'text': '5.', 'x0': 85.08, 'x1': 94.732272, 'top': 697.8768, 'doctop': 2379.8768, 'bottom': 708.9168, 'upright': True, 'direction': 1}]
# ##########
# [오답피하기]
# [오답피하기]
# #########
# 오답피하기
# 오답피하기
# 지문 word
# []
# 문제 word
# [{'text': '6.', 'x0': 85.08, 'x1': 94.732272, 'top': 345.79679999999996, 'doctop': 2868.7968, 'bottom': 356.8368, 'upright': True, 'direction': 1}]
# ##########
# [오답피하기]
# [오답피하기]
# #########
# 오답피하기
# 오답피하기
# 지문 word
# []
# 문제 word
# [{'text': '7.', 'x0': 85.08, 'x1': 94.732272, 'top': 99.43680000000006, 'doctop': 3463.4368, 'bottom': 110.47680000000003, 'upright': True, 'direction': 1}, {'text': '8.', 'x0': 85.08, 'x1': 94.732272, 'top': 504.1968, 'doctop': 3868.1968, 'bottom': 515.2368, 'upright': True, 'direction': 1}]
# ##########
# [오답피하기]
# [10~13]
# [10~13]
# [주제]
# #########
# 오답피하기
# 10~13
# 10~13
# 주제
# 지문 word
# [{'text': '[10~13]', 'x0': 85.08, 'x1': 122.33227199999999, 'top': 433.87679999999995, 'doctop': 4638.8768, 'bottom': 444.91679999999997, 'upright': True, 'direction': 1}, {'text': '[10~13]', 'x0': 85.08, 'x1': 122.33227199999999, 'top': 469.03679999999997, 'doctop': 4674.0368, 'bottom': 480.0768, 'upright': True, 'direction': 1}]
# 문제 word
# [{'text': '9.', 'x0': 85.08, 'x1': 94.732272, 'top': 257.83680000000004, 'doctop': 4462.8368, 'bottom': 268.8768, 'upright': True, 'direction': 1}, {'text': '10.', 'x0': 85.08, 'x1': 100.732512, 'top': 680.2368, 'doctop': 4885.2368, 'bottom': 691.2768, 'upright': True, 'direction': 1}]
# ##########
# [오답피하기]
# [오답피하기]
# [오답피하기]
# #########
# 오답피하기
# 오답피하기
# 오답피하기
# 지문 word
# []
# 문제 word
# [{'text': '11.', 'x0': 85.08, 'x1': 100.732512, 'top': 328.2768, 'doctop': 5374.2768, 'bottom': 339.3168, 'upright': True, 'direction': 1}, {'text': '12.', 'x0': 85.08, 'x1': 100.732512, 'top': 592.2768, 'doctop': 5638.2768, 'bottom': 603.3168, 'upright': True, 'direction': 1}]
# ##########
# [오답피하기]
# [14~17]
# [14~17]
# #########
# 오답피하기
# 14~17
# 14~17
# 지문 word
# [{'text': '[14~17]', 'x0': 85.08, 'x1': 122.33227199999999, 'top': 574.6368, 'doctop': 6461.6368, 'bottom': 585.6768, 'upright': True, 'direction': 1}, {'text': '[14~17]', 'x0': 85.08, 'x1': 122.33227199999999, 'top': 609.7968, 'doctop': 6496.7968, 'bottom': 620.8367999999999, 'upright': True, 'direction': 1}]
# 문제 word
# [{'text': '13.', 'x0': 85.08, 'x1': 100.732512, 'top': 205.03680000000008, 'doctop': 6092.0368, 'bottom': 216.07680000000005, 'upright': True, 'direction': 1}]
# ##########
# [주제]
# [오답피하기]
# #########
# 주제
# 오답피하기
# 지문 word
# []
# 문제 word
# [{'text': '14.', 'x0': 85.08, 'x1': 100.732512, 'top': 169.8768, 'doctop': 6897.8768, 'bottom': 180.91679999999997, 'upright': True, 'direction': 1}, {'text': '15.', 'x0': 85.08, 'x1': 100.732512, 'top': 539.4767999999999, 'doctop': 7267.4768, 'bottom': 550.5168, 'upright': True, 'direction': 1}]
# ##########
# [오답피하기]
# [오답피하기]
# #########
# 오답피하기
# 오답피하기
# 지문 word
# []
# 문제 word
# [{'text': '16.', 'x0': 85.08, 'x1': 100.732512, 'top': 99.43680000000006, 'doctop': 7668.4368, 'bottom': 110.47680000000003, 'upright': True, 'direction': 1}, {'text': '20.9-19.6=1.3명이다.', 'x0': 113.52, 'x1': 220.0128, 'top': 240.19680000000005, 'doctop': 7809.1968, 'bottom': 251.23680000000002, 'upright': True, 'direction': 1}, {'text': '1.3-(-2.1)=3.4명', 'x0': 400.44, 'x1': 483.1488, 'top': 310.6368, 'doctop': 7879.6368, 'bottom': 321.67679999999996, 'upright': True, 'direction': 1}, {'text': '–2.1의', 'x0': 477.12, 'x1': 510.2688, 'top': 363.43679999999995, 'doctop': 7932.4367999999995, 'bottom': 374.47679999999997, 'upright': True, 'direction': 1}, {'text': '17.', 'x0': 85.08, 'x1': 100.732512, 'top': 416.23679999999996, 'doctop': 7985.2368, 'bottom': 427.2768, 'upright': True, 'direction': 1}]
# ##########
# [18~21]
# [18-21]
# [주제]
# [오답피하기]
# [오답피하기]
# #########
# 18~21
# 18-21
# 주제
# 오답피하기
# 오답피하기
# 지문 word
# [{'text': '[18~21]', 'x0': 85.08, 'x1': 122.33227199999999, 'top': 99.43680000000006, 'doctop': 8509.4368, 'bottom': 110.47680000000003, 'upright': True, 'direction': 1}]
# 문제 word
# [{'text': '18.', 'x0': 85.08, 'x1': 100.732512, 'top': 328.2768, 'doctop': 8738.2768, 'bottom': 339.3168, 'upright': True, 'direction': 1}, {'text': '19.', 'x0': 85.08, 'x1': 100.732512, 'top': 539.4767999999999, 'doctop': 8949.4768, 'bottom': 550.5168, 'upright': True, 'direction': 1}]
# ##########
# [오답피하기]
# [오답피하기]
# #########
# 오답피하기
# 오답피하기
# 지문 word
# []
# 문제 word
# [{'text': '20.', 'x0': 85.08, 'x1': 100.732512, 'top': 117.07680000000005, 'doctop': 9368.0768, 'bottom': 128.1168, 'upright': True, 'direction': 1}, {'text': '21.', 'x0': 85.08, 'x1': 100.732512, 'top': 416.23679999999996, 'doctop': 9667.2368, 'bottom': 427.2768, 'upright': True, 'direction': 1}]
# ##########
# [22~27]
# [22-27]
# [주제]
# [주제]
# [주제]
# #########
# 22~27
# 22-27
# 주제
# 주제
# 주제
# 지문 word
# [{'text': '[22~27]', 'x0': 85.08, 'x1': 122.33227199999999, 'top': 169.8768, 'doctop': 10261.8768, 'bottom': 180.91679999999997, 'upright': True, 'direction': 1}]
# 문제 word
# [{'text': '22.', 'x0': 85.08, 'x1': 100.732512, 'top': 715.3968, 'doctop': 10807.3968, 'bottom': 726.4368, 'upright': True, 'direction': 1}]
# ##########
# [오답피하기]
# [오답피하기]
# #########
# 오답피하기
# 오답피하기
# 지문 word
# []
# 문제 word
# [{'text': '23.', 'x0': 85.08, 'x1': 100.732512, 'top': 433.87679999999995, 'doctop': 11366.8768, 'bottom': 444.91679999999997, 'upright': True, 'direction': 1}, {'text': '24.', 'x0': 85.08, 'x1': 100.732512, 'top': 697.8768, 'doctop': 11630.8768, 'bottom': 708.9168, 'upright': True, 'direction': 1}]
# ##########
# [오답피하기]
# [오답피하기]
# [오답피하기]
# #########
# 오답피하기
# 오답피하기
# 오답피하기
# 지문 word
# []
# 문제 word
# [{'text': '25.', 'x0': 85.08, 'x1': 100.732512, 'top': 310.6368, 'doctop': 12084.6368, 'bottom': 321.67679999999996, 'upright': True, 'direction': 1}, {'text': '26.', 'x0': 85.08, 'x1': 100.732512, 'top': 609.7968, 'doctop': 12383.7968, 'bottom': 620.8367999999999, 'upright': True, 'direction': 1}]
# ##########
# [오답피하기]
# [28~31]
# [28-31]
# [주제]
# #########
# 오답피하기
# 28~31
# 28-31
# 주제
# 지문 word
# [{'text': '[28~31]', 'x0': 85.08, 'x1': 122.33227199999999, 'top': 574.6368, 'doctop': 13189.6368, 'bottom': 585.6768, 'upright': True, 'direction': 1}]
# 문제 word
# [{'text': '27.', 'x0': 85.08, 'x1': 100.732512, 'top': 275.4768, 'doctop': 12890.4768, 'bottom': 286.5168, 'upright': True, 'direction': 1}]
# ##########
# [오답피하기]
# [오답피하기]
# [오답피하기]
# #########
# 오답피하기
# 오답피하기
# 오답피하기
# 지문 word
# []
# 문제 word
# [{'text': '28.', 'x0': 85.08, 'x1': 100.732512, 'top': 117.07680000000005, 'doctop': 13573.0768, 'bottom': 128.1168, 'upright': True, 'direction': 1}, {'text': '29.', 'x0': 85.08, 'x1': 100.732512, 'top': 416.23679999999996, 'doctop': 13872.2368, 'bottom': 427.2768, 'upright': True, 'direction': 1}, {'text': '30.', 'x0': 85.08, 'x1': 100.732512, 'top': 627.4368000000001, 'doctop': 14083.4368, 'bottom': 638.4768, 'upright': True, 'direction': 1}]
# ##########
# [E]에서
# [오답피하기]
# [A]에서
# [B]에서
# [C]에서
# [D]에서
# [32~34]
# [32-34]
# #########
# E
# 오답피하기
# A
# B
# C
# D
# 32~34
# 32-34
# 지문 word
# [{'text': '[32~34]', 'x0': 85.08, 'x1': 122.33227199999999, 'top': 645.0768, 'doctop': 14942.0768, 'bottom': 656.1168, 'upright': True, 'direction': 1}]
# 문제 word
# [{'text': '31.', 'x0': 85.08, 'x1': 100.732512, 'top': 275.4768, 'doctop': 14572.4768, 'bottom': 286.5168, 'upright': True, 'direction': 1}]
# ##########
# [주제]
# [주제]
# [오답피하기]
# #########
# 주제
# 주제
# 오답피하기
# 지문 word
# []
# 문제 word
# [{'text': '32.', 'x0': 85.08, 'x1': 100.732512, 'top': 504.1968, 'doctop': 15642.1968, 'bottom': 515.2368, 'upright': True, 'direction': 1}]
# ##########
# [오답피하기]
# [오답피하기]
# #########
# 오답피하기
# 오답피하기
# 지문 word
# []
# 문제 word
# [{'text': '33.', 'x0': 85.08, 'x1': 100.732512, 'top': 257.83680000000004, 'doctop': 16236.836800000001, 'bottom': 268.8768, 'upright': True, 'direction': 1}, {'text': '34.', 'x0': 85.08, 'x1': 100.732512, 'top': 592.2768, 'doctop': 16571.2768, 'bottom': 603.3168, 'upright': True, 'direction': 1}]
# ##########
# #########
# 지문 word
# []
# 문제 word
# []
# ##########
# [선택:
# [35~36]
# [35~36]
# [주제]
# ‘[밤만]’을
# [오답피하기]
# [목]’의
# [암닐]’에서는
# #########
# 35~36
# 35~36
# 주제
# 밤만
# 오답피하기
# 목
# 암닐
# 지문 word
# [{'text': '[35~36]', 'x0': 85.08, 'x1': 122.33227199999999, 'top': 202.39679999999998, 'doctop': 17863.3968, 'bottom': 213.43679999999995, 'upright': True, 'direction': 1}, {'text': '[35~36]', 'x0': 85.08, 'x1': 122.33227199999999, 'top': 237.55680000000007, 'doctop': 17898.5568, 'bottom': 248.59680000000003, 'upright': True, 'direction': 1}]
# 문제 word
# [{'text': '35.', 'x0': 93.11999999999999, 'x1': 107.346864, 'top': 131.65319999999997, 'doctop': 17792.6532, 'bottom': 141.6132, 'upright': True, 'direction': 1}, {'text': '36.', 'x0': 135.72, 'x1': 149.94686399999998, 'top': 131.65319999999997, 'doctop': 17792.6532, 'bottom': 141.6132, 'upright': True, 'direction': 1}, {'text': '37.', 'x0': 178.2, 'x1': 192.426864, 'top': 131.65319999999997, 'doctop': 17792.6532, 'bottom': 141.6132, 'upright': True, 'direction': 1}, {'text': '38.', 'x0': 220.67999999999998, 'x1': 234.90686399999996, 'top': 131.65319999999997, 'doctop': 17792.6532, 'bottom': 141.6132, 'upright': True, 'direction': 1}, {'text': '39.', 'x0': 263.28, 'x1': 277.506864, 'top': 131.65319999999997, 'doctop': 17792.6532, 'bottom': 141.6132, 'upright': True, 'direction': 1}, {'text': '40.', 'x0': 305.76, 'x1': 319.986864, 'top': 131.65319999999997, 'doctop': 17792.6532, 'bottom': 141.6132, 'upright': True, 'direction': 1}, {'text': '41.', 'x0': 348.24, 'x1': 362.46686400000004, 'top': 131.65319999999997, 'doctop': 17792.6532, 'bottom': 141.6132, 'upright': True, 'direction': 1}, {'text': '42.', 'x0': 390.84, 'x1': 405.066864, 'top': 131.65319999999997, 'doctop': 17792.6532, 'bottom': 141.6132, 'upright': True, 'direction': 1}, {'text': '43.', 'x0': 433.32, 'x1': 447.546864, 'top': 131.65319999999997, 'doctop': 17792.6532, 'bottom': 141.6132, 'upright': True, 'direction': 1}, {'text': '44.', 'x0': 475.79999999999995, 'x1': 490.026864, 'top': 131.65319999999997, 'doctop': 17792.6532, 'bottom': 141.6132, 'upright': True, 'direction': 1}, {'text': '45.', 'x0': 93.11999999999999, 'x1': 107.346864, 'top': 150.1332, 'doctop': 17811.1332, 'bottom': 160.09320000000002, 'upright': True, 'direction': 1}, {'text': '35.', 'x0': 85.08, 'x1': 100.732512, 'top': 431.23679999999996, 'doctop': 18092.2368, 'bottom': 442.2768, 'upright': True, 'direction': 1}, {'text': '36.', 'x0': 85.08, 'x1': 100.732512, 'top': 695.2368, 'doctop': 18356.2368, 'bottom': 706.2768, 'upright': True, 'direction': 1}]
# ##########
# [너코]’에서는
# [구지]’에서는
# [오답피하기]
# [장미꼳]’에서는
# [걱쩡]’에서는
# [오답피하기]
# [오답피하기]
# [오답피하기]
# #########
# 너코
# 구지
# 오답피하기
# 장미꼳
# 걱쩡
# 오답피하기
# 오답피하기
# 오답피하기
# 지문 word
# []
# 문제 word
# [{'text': '37.', 'x0': 85.08, 'x1': 100.732512, 'top': 292.9968, 'doctop': 18794.9968, 'bottom': 304.03679999999997, 'upright': True, 'direction': 1}, {'text': '38.', 'x0': 85.08, 'x1': 100.732512, 'top': 486.67679999999996, 'doctop': 18988.6768, 'bottom': 497.7168, 'upright': True, 'direction': 1}, {'text': '39.', 'x0': 85.08, 'x1': 100.732512, 'top': 627.4368000000001, 'doctop': 19129.4368, 'bottom': 638.4768, 'upright': True, 'direction': 1}]
# ##########
# [40~43]
# [오답피하기]
# [오답피하기]
# #########
# 40~43
# 오답피하기
# 오답피하기
# 지문 word
# [{'text': '[40~43]', 'x0': 85.08, 'x1': 122.33227199999999, 'top': 222.67680000000007, 'doctop': 19565.6768, 'bottom': 233.71680000000003, 'upright': True, 'direction': 1}]
# 문제 word
# [{'text': '40.', 'x0': 85.08, 'x1': 100.732512, 'top': 257.83680000000004, 'doctop': 19600.8368, 'bottom': 268.8768, 'upright': True, 'direction': 1}, {'text': '41.', 'x0': 85.08, 'x1': 100.732512, 'top': 539.4767999999999, 'doctop': 19882.4768, 'bottom': 550.5168, 'upright': True, 'direction': 1}]
# ##########
# [오답피하기]
# [오답피하기]
# [44~45]
# #########
# 오답피하기
# 오답피하기
# 44~45
# 지문 word
# [{'text': '[44~45]', 'x0': 85.08, 'x1': 122.33227199999999, 'top': 697.8768, 'doctop': 20881.8768, 'bottom': 708.9168, 'upright': True, 'direction': 1}]
# 문제 word
# [{'text': '42.', 'x0': 85.08, 'x1': 100.732512, 'top': 152.23680000000002, 'doctop': 20336.2368, 'bottom': 163.27679999999998, 'upright': True, 'direction': 1}, {'text': '43.', 'x0': 85.08, 'x1': 100.732512, 'top': 416.23679999999996, 'doctop': 20600.2368, 'bottom': 427.2768, 'upright': True, 'direction': 1}, {'text': '44.', 'x0': 85.08, 'x1': 100.732512, 'top': 733.0368, 'doctop': 20917.0368, 'bottom': 744.0767999999999, 'upright': True, 'direction': 1}]
# ##########
# [오답피하기]
# [C]에서
# [오답피하기]
# [A]에서
# [B]에서
# [D]에서
# [E]에서
# #########
# 오답피하기
# C
# 오답피하기
# A
# B
# D
# E
# 지문 word
# []
# 문제 word
# [{'text': '45.', 'x0': 85.08, 'x1': 100.732512, 'top': 345.79679999999996, 'doctop': 21370.7968, 'bottom': 356.8368, 'upright': True, 'direction': 1}]
# (578, 1195)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# (1894, 1259)
# parse pdf/explanation/2022_6_media.pdf complete
